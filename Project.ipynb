# %%
import pandas as pd
import pandas as pd # step 1:-import neccessary library 
import matplotlib 
# %matplotlib inline
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import numpy as np

# %%
data=pd.read_csv("cardekho.csv") # step 2:- read data

# %%
data.head()
# Out:
#    Unnamed: 0       car_name    brand     model  min_cost_price  \
# 0           0    Maruti Alto   Maruti      Alto    3.570039e+05
# 1           1  Hyundai Grand  Hyundai     Grand    7.110000e+05
# 2           2    Hyundai i20  Hyundai       i20    8.540829e+05
# 3           3    Maruti Alto   Maruti      Alto    3.570039e+05
# 4           4  Ford Ecosport     Ford  Ecosport    1.014000e+06
#
#    max_cost_price  vehicle_age  km_driven seller_type fuel_type  \
# 0    4.654015e+05            9     120000  Individual    Petrol
# 1    7.480000e+05            5      20000  Individual    Petrol
# 2    1.307926e+06           11      60000  Individual    Petrol
# 3    4.654015e+05            9      37000  Individual    Petrol
# 4    1.379000e+06            6      30000      Dealer    Diesel
#
#   transmission_type  mileage  engine  max_power  seats  selling_price
# 0            Manual    19.70     796      46.30      5         120000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15411 entries, 0 to 15410
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         15411 non-null  int64
#  1   car_name           15411 non-null  object
#  2   brand              15411 non-null  object
#  3   model              15411 non-null  object
#  4   min_cost_price     15411 non-null  float64
#  5   max_cost_price     15411 non-null  float64
#  6   vehicle_age        15411 non-null  int64
#  7   km_driven          15411 non-null  int64
#  8   seller_type        15411 non-null  object
#  9   fuel_type          15411 non-null  object
#  10  transmission_type  15411 non-null  object
#  11  mileage            15411 non-null  float64
#  12  engine             15411 non-null  int64
#  13  max_power          15411 non-null  float64
#  14  seats              15411 non-null  int64
#  15  selling_price      15411 non-null  int64
# ...

# %%
data['fuel_type'].value_counts()
# Out:
# Petrol      7643
# Diesel      7419
# CNG          301
# LPG           44
# Electric       4
# Name: fuel_type, dtype: int64

# %%
data['seller_type'].value_counts()
# Out:
# Dealer              9539
# Individual          5699
# Trustmark Dealer     173
# Name: seller_type, dtype: int64

# %%
data.replace({'fuel_type':{'Petrol':0,'Diesel':1,'CNG':2,'LPG':3,'Electric':4}}).head() #we have converted fuel type of vehical by assigning integer.
# Out:
#    Unnamed: 0       car_name    brand     model  min_cost_price  \
# 0           0    Maruti Alto   Maruti      Alto    3.570039e+05
# 1           1  Hyundai Grand  Hyundai     Grand    7.110000e+05
# 2           2    Hyundai i20  Hyundai       i20    8.540829e+05
# 3           3    Maruti Alto   Maruti      Alto    3.570039e+05
# 4           4  Ford Ecosport     Ford  Ecosport    1.014000e+06
#
#    max_cost_price  vehicle_age  km_driven seller_type  fuel_type  \
# 0    4.654015e+05            9     120000  Individual          0
# 1    7.480000e+05            5      20000  Individual          0
# 2    1.307926e+06           11      60000  Individual          0
# 3    4.654015e+05            9      37000  Individual          0
# 4    1.379000e+06            6      30000      Dealer          1
#
#   transmission_type  mileage  engine  max_power  seats  selling_price
# 0            Manual    19.70     796      46.30      5         120000
# ...

# %%
data.replace({'seller_type':{'Dealer':0,'Individual':1,'Trustmark Dealer':2}}).head()#we have converted Seller type of vehical by assigning integer.
# Out:
#    Unnamed: 0       car_name    brand     model  min_cost_price  \
# 0           0    Maruti Alto   Maruti      Alto    3.570039e+05
# 1           1  Hyundai Grand  Hyundai     Grand    7.110000e+05
# 2           2    Hyundai i20  Hyundai       i20    8.540829e+05
# 3           3    Maruti Alto   Maruti      Alto    3.570039e+05
# 4           4  Ford Ecosport     Ford  Ecosport    1.014000e+06
#
#    max_cost_price  vehicle_age  km_driven  seller_type fuel_type  \
# 0    4.654015e+05            9     120000            1    Petrol
# 1    7.480000e+05            5      20000            1    Petrol
# 2    1.307926e+06           11      60000            1    Petrol
# 3    4.654015e+05            9      37000            1    Petrol
# 4    1.379000e+06            6      30000            0    Diesel
#
#   transmission_type  mileage  engine  max_power  seats  selling_price
# 0            Manual    19.70     796      46.30      5         120000
# ...

# %%
data.hist(bins=50,figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'min_cost_price'}>,
#         <AxesSubplot:title={'center':'max_cost_price'}>],
#        [<AxesSubplot:title={'center':'vehicle_age'}>,
#         <AxesSubplot:title={'center':'km_driven'}>,
#         <AxesSubplot:title={'center':'mileage'}>],
#        [<AxesSubplot:title={'center':'engine'}>,
#         <AxesSubplot:title={'center':'max_power'}>,
#         <AxesSubplot:title={'center':'seats'}>],
#        [<AxesSubplot:title={'center':'selling_price'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
corr_matrix=data.corr()

# %%
corr_matrix['selling_price'].sort_values(ascending=False)
# Out:
# selling_price     1.000000
# max_power         0.750236
# max_cost_price    0.719937
# engine            0.585844
# min_cost_price    0.225362
# seats             0.115033
# Unnamed: 0        0.030523
# km_driven        -0.080030
# vehicle_age      -0.241851
# mileage          -0.305549
# Name: selling_price, dtype: float64

# %%
attr=['selling_price','max_cost_price','km_driven','vehicle_age']
scatter_matrix(data[attr],figsize=(25,25))
# Out:
# array([[<AxesSubplot:xlabel='selling_price', ylabel='selling_price'>,
#         <AxesSubplot:xlabel='max_cost_price', ylabel='selling_price'>,
#         <AxesSubplot:xlabel='km_driven', ylabel='selling_price'>,
#         <AxesSubplot:xlabel='vehicle_age', ylabel='selling_price'>],
#        [<AxesSubplot:xlabel='selling_price', ylabel='max_cost_price'>,
#         <AxesSubplot:xlabel='max_cost_price', ylabel='max_cost_price'>,
#         <AxesSubplot:xlabel='km_driven', ylabel='max_cost_price'>,
#         <AxesSubplot:xlabel='vehicle_age', ylabel='max_cost_price'>],
#        [<AxesSubplot:xlabel='selling_price', ylabel='km_driven'>,
#         <AxesSubplot:xlabel='max_cost_price', ylabel='km_driven'>,
#         <AxesSubplot:xlabel='km_driven', ylabel='km_driven'>,
#         <AxesSubplot:xlabel='vehicle_age', ylabel='km_driven'>],
#        [<AxesSubplot:xlabel='selling_price', ylabel='vehicle_age'>,
#         <AxesSubplot:xlabel='max_cost_price', ylabel='vehicle_age'>,
# ...

# %%
data.plot(kind="scatter",x="km_driven",y="selling_price")
# Out:
# <AxesSubplot:xlabel='km_driven', ylabel='selling_price'>

# %%
plt.scatter(data.vehicle_age,data.selling_price)
plt.title("Age Vs selling_price")
plt.xlabel("Age Of Vehical")
plt.ylabel("selling_price")
plt.xlim(0,35)
plt.ylim(0,500000)
# Out:
# (0.0, 500000.0)

# %%
plt.scatter(data.km_driven,data.selling_price)
plt.title("KM _driven Vs selling_price")
plt.xlabel("kilometer Driven")
plt.ylabel("selling_price in lacks")
plt.xlim(0,30000)
# Out:
# (0.0, 30000.0)
